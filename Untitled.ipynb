# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
G = nx.read_edgelist('trust.txt', nodetype=int, data=(('weight',float),), create_using=nx.DiGraph())
nx.draw(G)
plt.show()

# %%
df=pd.read_csv('ratings.txt',sep='\s',engine='python')
df.columns = ["user_id", "item_id", "rating"]
df.sort_values(['user_id','item_id'], inplace = True, ascending=True)

# %%
trust_rating_common = pd.DataFrame()
user_set=list(map(int,list(df['user_id'])))
item_set=list(map(int,list(df['item_id'])))
rating=list(map(int,list(df['rating'])))
trust_user=G.nodes(data=False)
user=list(set(user_set).intersection(trust_user))

# %%
for i in user:
    trust_rating_common = trust_rating_common.append(df[df.user_id == i])

# %%
trust_rating_common.count()
# Out:
# user_id    18662
# item_id    18662
# rating     18662
# dtype: int64

# %%
trust_rating_common.tail()
# Out:
#        user_id  item_id  rating
# 35494     1508      669     1.0
# 35495     1508      686     2.5
# 35470     1508      693     3.5
# 35477     1508      751     1.0
# 35496     1508      806     3.5

# %%
trust_rating_common.head()
# Out:
#      user_id  item_id  rating
# 12         2       13     2.0
# 209        4        1     3.0
# 207        4        3     2.5
# 211        4       17     0.5
# 206        4      205     3.0

# %% [markdown]
# Creation of Bipartite graph from the rating data of common users (users present in both rating and trust)

# %%
rating_bipartite_G = nx.Graph()
common_users_itemlist =trust_rating_common['item_id'].unique()
common_users_itemlist.sort()
item_set = ['NA']*len(common_users_itemlist);
for i in range(len(common_users_itemlist)):
    item_set[i] = 'i_'+str(common_users_itemlist[i])

# %%
print(item_set)
# Out:
# ['i_1', 'i_2', 'i_3', 'i_4', 'i_5', 'i_6', 'i_7', 'i_8', 'i_9', 'i_10', 'i_11', 'i_12', 'i_13', 'i_14', 'i_15', 'i_16', 'i_17', 'i_18', 'i_19', 'i_20', 'i_21', 'i_22', 'i_24', 'i_25', 'i_26', 'i_28', 'i_29', 'i_30', 'i_31', 'i_32', 'i_34', 'i_35', 'i_36', 'i_37', 'i_38', 'i_39', 'i_40', 'i_41', 'i_42', 'i_43', 'i_44', 'i_45', 'i_46', 'i_48', 'i_49', 'i_50', 'i_51', 'i_52', 'i_53', 'i_54', 'i_55', 'i_56', 'i_57', 'i_58', 'i_59', 'i_60', 'i_61', 'i_62', 'i_63', 'i_64', 'i_65', 'i_66', 'i_67', 'i_69', 'i_70', 'i_71', 'i_72', 'i_73', 'i_75', 'i_76', 'i_77', 'i_78', 'i_80', 'i_81', 'i_82', 'i_83', 'i_84', 'i_85', 'i_86', 'i_87', 'i_88', 'i_89', 'i_90', 'i_91', 'i_92', 'i_93', 'i_94', 'i_95', 'i_96', 'i_97', 'i_98', 'i_99', 'i_100', 'i_102', 'i_103', 'i_105', 'i_106', 'i_107', 'i_108', 'i_110', 'i_112', 'i_113', 'i_114', 'i_115', 'i_116', 'i_117', 'i_118', 'i_119', 'i_120', 'i_121', 'i_122', 'i_123', 'i_124', 'i_125', 'i_126', 'i_127', 'i_128', 'i_129', 'i_130', 'i_131', 'i_132', 'i_134', 'i_135', 'i_136', 'i_137', 'i_139', 'i_141', 'i_142', 'i_143', 'i_144', 'i_145', 'i_146', 'i_147', 'i_148', 'i_149', 'i_150', 'i_151', 'i_152', 'i_153', 'i_154', 'i_155', 'i_156', 'i_157', 'i_158', 'i_159', 'i_160', 'i_161', 'i_162', 'i_163', 'i_165', 'i_166', 'i_167', 'i_168', 'i_169', 'i_170', 'i_171', 'i_172', 'i_173', 'i_174', '
# %%
user_set = ['NA']*len(user);
for i in range(len(user)):
    user_set[i] = 'u_'+str(user[i])

# %%
print(user_set)
# Out:
# ['u_2', 'u_4', 'u_5', 'u_6', 'u_7', 'u_12', 'u_13', 'u_15', 'u_16', 'u_18', 'u_20', 'u_23', 'u_26', 'u_27', 'u_29', 'u_32', 'u_35', 'u_36', 'u_38', 'u_42', 'u_43', 'u_47', 'u_51', 'u_57', 'u_58', 'u_60', 'u_61', 'u_62', 'u_63', 'u_66', 'u_71', 'u_74', 'u_78', 'u_79', 'u_80', 'u_83', 'u_84', 'u_85', 'u_86', 'u_88', 'u_89', 'u_90', 'u_91', 'u_92', 'u_93', 'u_94', 'u_95', 'u_96', 'u_99', 'u_100', 'u_103', 'u_104', 'u_106', 'u_109', 'u_110', 'u_112', 'u_114', 'u_115', 'u_116', 'u_120', 'u_123', 'u_125', 'u_129', 'u_134', 'u_135', 'u_141', 'u_143', 'u_146', 'u_147', 'u_149', 'u_150', 'u_151', 'u_154', 'u_159', 'u_160', 'u_161', 'u_162', 'u_163', 'u_164', 'u_165', 'u_166', 'u_167', 'u_168', 'u_169', 'u_170', 'u_171', 'u_173', 'u_174', 'u_175', 'u_177', 'u_182', 'u_188', 'u_191', 'u_192', 'u_193', 'u_195', 'u_196', 'u_199', 'u_200', 'u_201', 'u_208', 'u_210', 'u_213', 'u_215', 'u_217', 'u_220', 'u_221', 'u_222', 'u_223', 'u_224', 'u_226', 'u_227', 'u_228', 'u_230', 'u_231', 'u_232', 'u_234', 'u_238', 'u_239', 'u_240', 'u_241', 'u_242', 'u_244', 'u_249', 'u_253', 'u_254', 'u_256', 'u_261', 'u_262', 'u_263', 'u_264', 'u_265', 'u_267', 'u_268', 'u_269', 'u_271', 'u_272', 'u_273', 'u_274', 'u_278', 'u_281', 'u_282', 'u_284', 'u_285', 'u_291', 'u_294', 'u_295', 'u_297', 'u_298', 'u_300', 'u_301', 'u_302', 'u_304', 'u_305', 'u_306', 'u_307', 'u_310', 'u_312', 'u_313', 'u_314', 'u_315', 'u_316', 'u_317', 'u_319', 'u_320', 'u_321', 'u_322', 'u_323', 'u_324', 'u_327', 'u_328', 'u_329', 'u_332', 'u_334', 'u_336', 'u_337', 'u_339', 'u_340', 'u_341', 'u_343', 'u_345', 'u_348', 'u_353', 'u_355', 'u_361', 'u_362', 'u_364', 'u_368', 'u_372', 'u_373', 'u_378', 'u_379', 'u_380', 'u_382', 'u_384', 'u_387', 'u_392', 'u_393', 'u_394', 'u_395', 'u_396', 'u_397', 'u_399', 'u_402', 'u_403', 'u_406', 'u_407', 'u_409', 'u_410', 'u_411', 'u_416', 'u_417', 'u_420', 'u_422', 'u_423', 'u_425', 'u_426', 'u_427', 'u_428', 'u_430', 'u_432', 'u_433', 'u_436', 'u_441', 'u_445', 'u_447', 'u_448', 'u_452', 'u_457', 'u_458', 'u_463', 'u_464', 'u_467', 'u_468', 'u_471', 'u_472', 'u_473', 'u_476', 'u_477', 'u_478', 'u_480', 'u_481', 'u_483', 'u_484', 'u_485', 'u_488', 'u_489', 'u_490', 'u_491', 'u_493', 'u_495', 'u_496', 'u_499', 'u_502', 'u_503', 'u_506', 'u_507', 'u_508', 'u_509', 'u_510', 'u_511', 'u_514', 'u_516', 'u_521', 'u_524', 'u_528', 'u_532', 'u_533', 'u_534', 'u_535', 'u_537', 'u_539', 'u_542', 'u_543', 'u_544', 'u_546', 'u_548', 'u_550', 'u_552', 'u_553', 'u_554', 'u_556', 'u_561', 'u_562', 'u_563', 'u_564', 'u_568', 'u_571', 'u_574', 'u_577', 'u_578', 'u_580', 'u_581', 'u_584', 'u_591', 'u_593', 'u_595', 'u_598', 'u_605', 'u_606', 'u_607', 'u_612', 'u_616', 'u_617', 'u_618', 'u_619', 'u_620', 'u_623', 'u_624', 'u_626', 'u_628', 'u_629', 'u_630', 'u_631', 'u_632', 'u_633', 'u_634', 'u_636', 'u_637', 'u_638', 'u_640', 'u_644', 'u_645', 'u_648', 'u_649', 'u_652', 'u_653', 'u_655', 'u_658', 'u_659', 'u_661', 'u_663', 'u_665', 'u_666', 'u_670', 'u_671', 'u_672', 'u_676', 'u_678', 'u_679', 'u_680', 'u_681', 'u_682', 'u_683', 'u_684', 'u_685', 'u_694', 'u_695', 'u_696', 'u_698', 'u_702', 'u_703', 'u_705', 'u_706', 'u_707', 'u_711', 'u_712', 'u_716', 'u_718', 'u_720', 'u_721', 'u_724', 'u_725', 'u_728', 'u_732', 'u_733', 'u_735', 'u_737', 'u_738', 'u_739', 'u_740', 'u_741', 'u_743', 'u_745', 'u_748', 'u_752', 'u_754', 'u_755', 'u_759', 'u_762', 'u_764', 'u_769', 'u_771', 'u_772', 'u_773', 'u_774', 'u_775', 'u_776', 'u_777', 'u_781', 'u_782', 'u_788', 'u_790', 'u_791', 'u_792', 'u_795', 'u_798', 'u_803', 'u_804', 'u_805', 'u_806', 'u_807', 'u_808', 'u_810', 'u_812', 'u_813', 'u_814', 'u_821', 'u_824', 'u_825', 'u_826', 'u_828', 'u_830', 'u_832', 'u_837', 'u_838', 'u_842', 'u_843', 'u_845', 'u_847', 'u_849', 'u_853', 'u_854', 'u_857', 'u_858', 'u_859', 'u_861', 'u_862', 'u_863', 'u_865', 'u_867', 'u_868', 'u_872', 'u_873', 'u_876', 'u_877', 'u_883', 'u_892', 'u_897', 'u_898', 'u_900', 'u_903', 'u_905', 'u_906', 'u_909', 'u_911', 'u_914', 'u_915', 'u_918', 'u_919', 'u_ ...

# %%
rating_bipartite_G = nx.Graph()
rating_bipartite_G.add_nodes_from(user_set, bipartite =0)
rating_bipartite_G.add_nodes_from(item_set, bipartite =1)

# %%
for i in range(len(trust_rating_common)):
    rating_bipartite_G.add_edge('u_'+str(trust_rating_common.iloc[i,0]),'i_'+str(trust_rating_common.iloc[i,1]), weight=float(trust_rating_common.iloc[i,2]))

# %%
nx.draw(rating_bipartite_G, node_size=7, cmap=plt.cm.Blues,node_color=range(len(rating_bipartite_G)),prog='dot')
plt.show()

# %%
a=nx.all_pairs_shortest_path(rating_bipartite_G,cutoff=4)
class Generator:
    def __init__(self, gen):
        self.gen = gen

    def __iter__(self):
        self.value = yield from self.gen
d1={}
path=Generator(a)
for i in path:
    items=tuple(i[1].items())
    items=sorted(items,key=lambda x: len(x[1]),reverse=True)
    l1=[]
    for i in items:
        if len(i[1])>=3:
            l1+= i[1][1:-1]  #collecting nodes in the path of two nodes
            l1=(list(set(l1))) #removing duplicates
        else:
            continue
        d1[items[0][1][0]]=l1
        # remove comment from following lines to get an idea what this code is doing
        #print d1
        #break
